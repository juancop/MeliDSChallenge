# %%
from src import meliRetriever, getAPIkey

# %%
#get_token = getAPIkey()

# %%
#get_token.api_key

# %%
dff = meliRetriever(site_name = 'Colombia', token = "APP_USR-4892726125387151-122404-064f798f19765427c918409435f0c944-251350663")#get_token.api_key)

# %%
tmp_df = dff.create_dataset(file_name = 'data/ColombianData.csv')
# Out:
# N/A% (0 of 31) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# llegue a powerseller
# Pude hacer hasta ratings
# ...
