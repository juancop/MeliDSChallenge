# %%
from src import meliRetriever

# %%
dff = meliRetriever('Colombia')

# %%
dff.create_dataset(file_name = 'data/trial_data.csv')
# Out:
# 100% (31 of 31) |########################| Elapsed Time: 0:06:28 Time:  0:06:28
#                  id                                              title  \
# 0      MCO548989931  Espejo Retrovisor Punto Ciego 360 Grados  - 2 ...
# 1      MCO508601525  Forro Sillas Funda Protector Mascota Cobertor ...
# 2      MCO509093160  Radio Carro Bluetooth + Camara Usb Sd Pantalla...
# 3      MCO580695899  Casco Moto Integral Pro Tork New Liberty Four ...
# 4      MCO547297635  Espejo Retrovisor Punto Ciego 360  Convexo - 2...
# ...             ...                                                ...
# 32015  MCO473968001  Vh Essentials Supositorios Vaginales Prebiótic...
# 32016  MCO455605484  Set Para Hora Loca Personalizado Piñateria Acc...
# 32017  MCO469154434                      Protesis Mamarias  Por Unidad
# 32018  MCO452392793  Botellas Frascos  Invitaciones  Recordatorios ...
# 32019  MCO558907331   15 Minutos De Manifestación Eddie Sergey Orginal
#
#           price  available_quantity  sold_quantity buying_mode  \
# 0       11000.0                 100            500  buy_it_now
# 1       39900.0                 150            500  buy_it_now
# 2      230900.0                   1            500  buy_it_now
# 3       84900.0                 250            500  buy_it_now
# 4       18000.0                 100            250  buy_it_now
# ...         ...                 ...            ...         ...
# 32015   71990.0                   1              5  buy_it_now
# 32016   55000.0                 500              5  buy_it_now
# 32017  160000.0                   1              5  buy_it_now
# 32018   35000.0                  50            500  buy_it_now
# 32019    9500.0                  50              5  buy_it_now
#
#       listing_type_id  accepts_mercadopago original_price category_id  \
# 0        gold_special                 True            NaN   MCO174843
# 1        gold_special                 True            NaN   MCO178000
# 2        gold_special                 True         349900   MCO429530
# 3        gold_special                 True         129900    MCO21947
# 4        gold_special                 True            NaN   MCO174843
# ...               ...                  ...            ...         ...
# 32015    gold_special                 True           None     MCO3530
# 32016    gold_special                 True           None     MCO3530
# 32017    gold_special                 True           None     MCO3530
# 32018    gold_special                 True           None     MCO3530
# 32019        gold_pro                 True           None     MCO3530
#
#                    category_name
# 0      Accesorios para Vehículos
# 1      Accesorios para Vehículos
# 2      Accesorios para Vehículos
# 3      Accesorios para Vehículos
# 4      Accesorios para Vehículos
# ...                          ...
# 32015           Otras categorías
# 32016           Otras categorías
# 32017           Otras categorías
# 32018           Otras categorías
# 32019           Otras categorías
#
# [32020 rows x 11 columns]

# %%
dff = meliRetriever('Argentina')
dff.create_dataset(file_name = 'data/argentina_trial.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('data/trial_data.csv', sep = ";")

# %%
df['has_discount'] = pd.isna(df.original_price)

# %%
df['has_discount'].value_counts()
# Out:
# True     30136
# False     1884
# Name: has_discount, dtype: int64

# %%
df[!df.has_discount]
# Out:
#                  id                                              title  \
# 0      MCO548989931  Espejo Retrovisor Punto Ciego 360 Grados  - 2 ...
# 1      MCO508601525  Forro Sillas Funda Protector Mascota Cobertor ...
# 4      MCO547297635  Espejo Retrovisor Punto Ciego 360  Convexo - 2...
# 5      MCO464935021  Kit Panel Solar+4 Bombillos+batería+linterna A...
# 6      MCO560749645  Radio Carro Bluetooth + Camara Usb Sd Pantalla...
# ...             ...                                                ...
# 32015  MCO473968001  Vh Essentials Supositorios Vaginales Prebiótic...
# 32016  MCO455605484  Set Para Hora Loca Personalizado Piñateria Acc...
# 32017  MCO469154434                      Protesis Mamarias  Por Unidad
# 32018  MCO452392793  Botellas Frascos  Invitaciones  Recordatorios ...
# 32019  MCO558907331   15 Minutos De Manifestación Eddie Sergey Orginal
#
#           price  available_quantity  sold_quantity buying_mode  \
# 0       11000.0                 100            500  buy_it_now
# 1       39900.0                 150            500  buy_it_now
# 4       18000.0                 100            250  buy_it_now
# 5       89900.0                   1            500  buy_it_now
# 6      239900.0                   1            500  buy_it_now
# ...         ...                 ...            ...         ...
# 32015   71990.0                   1              5  buy_it_now
# 32016   55000.0                 500              5  buy_it_now
# 32017  160000.0                   1              5  buy_it_now
# 32018   35000.0                  50            500  buy_it_now
# 32019    9500.0                  50              5  buy_it_now
#
#       listing_type_id  accepts_mercadopago  original_price category_id  \
# 0        gold_special                 True             NaN   MCO174843
# 1        gold_special                 True             NaN   MCO178000
# 4        gold_special                 True             NaN   MCO174843
# 5        gold_special                 True             NaN    MCO87923
# 6        gold_special                 True             NaN     MCO3387
# ...               ...                  ...             ...         ...
# 32015    gold_special                 True             NaN     MCO3530
# 32016    gold_special                 True             NaN     MCO3530
# 32017    gold_special                 True             NaN     MCO3530
# 32018    gold_special                 True             NaN     MCO3530
# 32019        gold_pro                 True             NaN     MCO3530
#
#                    category_name  has_discount
# 0      Accesorios para Vehículos          True
# 1      Accesorios para Vehículos          True
# 4      Accesorios para Vehículos          True
# 5      Accesorios para Vehículos          True
# 6      Accesorios para Vehículos          True
# ...                          ...           ...
# 32015           Otras categorías          True
# 32016           Otras categorías          True
# 32017           Otras categorías          True
# 32018           Otras categorías          True
# 32019           Otras categorías          True
#
# [30136 rows x 12 columns]
